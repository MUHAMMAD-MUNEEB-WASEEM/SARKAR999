# %%
import os
import numpy as np
import matplotlib,pylab as plt
from PIL import Image

rootDir = "photos"
np_array = np.zeros([20,200,200,3])

def plti(im, h=8, **kwargs):
    """
    Helper function to plot an image.
    """
    y = im.shape[0]
    x = im.shape[1]
    w = (y/x) * h
    plt.figure(figsize=(w,h))
    plt.imshow(im, interpolation="none", **kwargs)
    plt.axis('off')

i = 0

for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
        print('Found directory: %s' % dirName)
        im = Image.open(rootDir +"/"+ fname)
        
        #im = plt.imread(rootDir +"/"+ fname)
        #plti(im)
        
        im = im.resize((200,200,))
        np_array[i] = np.asarray(im, dtype = "int32")
        print(np_array[i].shape)
        print(type(np_array[i] ))
        
        i = i+1

np_array
# Out:
# Found directory: photos
# 	1.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	10.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	11.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	12.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	13.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	14.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	15.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	16.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	17.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	18.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	19.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	2.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	20.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	3.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	4.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	5.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	6.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	7.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	8.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# 	9.jpg
# Found directory: photos
# (200, 200, 3)
# <class 'numpy.ndarray'>
# array([[[[242., 249., 242.],
#          [244., 254., 246.],
#          [249., 255., 251.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[252., 255., 251.],
#          [252., 255., 251.],
#          [251., 255., 251.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[252., 255., 251.],
#          [252., 255., 251.],
#          [251., 255., 251.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]]],
#
#
#        [[[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         ...,
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]]],
#
#
#        [[[  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          ...,
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.]],
#
#         [[  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          ...,
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.]],
#
#         [[  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          ...,
#          [  0.,  51., 153.],
#          [  0.,  51., 153.],
#          [  0.,  51., 153.]],
#
#         ...,
#
#         [[251., 251., 251.],
#          [251., 251., 251.],
#          [250., 250., 250.],
#          ...,
#          [ 13.,  18., 112.],
#          [ 16.,  15., 151.],
#          [ 16.,  15., 151.]],
#
#         [[254., 254., 252.],
#          [254., 254., 254.],
#          [252., 252., 252.],
#          ...,
#          [  7.,   6.,  99.],
#          [  5.,   1., 137.],
#          [  5.,   1., 137.]],
#
#         [[254., 254., 252.],
#          [254., 254., 254.],
#          [252., 252., 252.],
#          ...,
#          [ 79.,  78., 171.],
#          [ 77.,  74., 205.],
#          [ 77.,  74., 205.]]],
#
#
#        ...,
#
#
#        [[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]]],
#
#
#        [[[192., 193., 179.],
#          [186., 187., 173.],
#          [178., 179., 165.],
#          ...,
#          [182., 183., 169.],
#          [182., 183., 169.],
#          [187., 188., 174.]],
#
#         [[181., 182., 168.],
#          [175., 176., 162.],
#          [167., 168., 154.],
#          ...,
#          [171., 172., 158.],
#          [171., 172., 158.],
#          [176., 177., 163.]],
#
#         [[175., 176., 162.],
#          [169., 170., 156.],
#          [161., 162., 148.],
#          ...,
#          [165., 166., 152.],
#          [165., 166., 152.],
#          [170., 171., 157.]],
#
#         ...,
#
#         [[181., 182., 168.],
#          [175., 176., 162.],
#          [168., 169., 155.],
#          ...,
#          [168., 169., 155.],
#          [168., 169., 155.],
#          [174., 175., 161.]],
#
#         [[181., 182., 168.],
#          [175., 176., 162.],
#          [168., 169., 155.],
#          ...,
#          [171., 172., 158.],
#          [171., 172., 158.],
#          [176., 177., 163.]],
#
#         [[182., 183., 169.],
#          [176., 177., 163.],
#          [169., 170., 156.],
#          ...,
#          [174., 175., 161.],
#          [174., 175., 161.],
#          [180., 181., 167.]]],
#
#
#        [[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]]]])
